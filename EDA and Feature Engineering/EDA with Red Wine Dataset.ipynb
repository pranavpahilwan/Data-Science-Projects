# %% [markdown]
# # Red Wine Dataset

# %% [markdown]
# ### Dataset Information

# %% [markdown]
# ##### Dataset is present in UCI Machine Learning Repository
# The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. For more details, consult: http://www.vinhoverde.pt/en/ or the reference [Cortez et al., 2009].  Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# These datasets can be viewed as classification or regression tasks.  The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Outlier detection algorithms could be used to detect the few excellent or poor wines. Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.

# %% [raw]
# Input variables (based on physicochemical tests):
#    1 - fixed acidity
#    2 - volatile acidity
#    3 - citric acid
#    4 - residual sugar
#    5 - chlorides
#    6 - free sulfur dioxide
#    7 - total sulfur dioxide
#    8 - density
#    9 - pH
#    10 - sulphates
#    11 - alcohol
# Output variable (based on sensory data):
#    12 - quality (score between 0 and 10)

# %%
import pandas as pd

# %%
wine_data=pd.read_csv("E:\PRANAV\Study\Projects\EDA\wine+quality\winequality-red.csv")

# %%
wine_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# .info() gives all the features with data type and non-null count.
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# describe - generates descriptive statistics for each and every feature
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# gives the count of row and columns
wine_data.shape
# Out:
# (1599, 12)

# %%
# List down all the column name
wine_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
for i in wine_data:
    print(i)
# Out:
# fixed acidity
# volatile acidity
# citric acid
# residual sugar
# chlorides
# free sulfur dioxide
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# quality

# %%
wine_data['fixed acidity']
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
wine_data['quality']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
wine_data['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
wine_data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
wine_data[wine_data.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
wine_data[wine_data.duplicated()].count()
# Out:
# fixed acidity           240
# volatile acidity        240
# citric acid             240
# residual sugar          240
# chlorides               240
# free sulfur dioxide     240
# total sulfur dioxide    240
# density                 240
# pH                      240
# sulphates               240
# alcohol                 240
# quality                 240
# dtype: int64

# %% [markdown]
# Duplicate data can have detrimental effects on machine learning models and outcomes, such as reducing data diversity and representativeness, which can lead to overfitting or biased models.

# %%
# It is important to delete the duplicate entries from data.
wine_data.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_data.shape
# Out:
# (1599, 12)

# %%
# inplace =True helps to delete entries permenently
wine_data.drop_duplicates(inplace=True)

# %%
# we can see the no of entries after the deletion
wine_data.shape
# Out:
# (1359, 12)

# %%
wine_data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# We can see above the correlation of features with each other. -ve values shows Negative correlation and +ve values shows Positive correlation

# %% [markdown]
# we can use different correlation methods like- Spearman, pearson correlation

# %%
wine_data.corr(method='pearson')
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine_data.corr(method='spearman')
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.280162     0.657387
# volatile acidity          -0.280162          1.000000    -0.610925
# citric acid                0.657387         -0.610925     1.000000
# residual sugar             0.222396          0.031299     0.170096
# chlorides                  0.244095          0.170678     0.110679
# free sulfur dioxide       -0.157857          0.012162    -0.059585
# total sulfur dioxide      -0.083827          0.092548     0.021124
# density                    0.626628          0.032264     0.344303
# pH                        -0.708560          0.245973    -0.558594
# sulphates                  0.220696         -0.324207     0.341512
# alcohol                   -0.062696         -0.225714     0.090798
# quality                    0.111693         -0.387450     0.219427
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# we can see the correlation between features easily using heatmap
import seaborn as sns
sns.heatmap(wine_data.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(wine_data.corr(),annot=True) # annot=True shows the values of correlation
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.heatmap(wine_data.corr(),annot=True)
# Out:
# <Axes: >

# %%
wine_data.quality.value_counts() 
# Here we can see the data is imbalanced
# If we have to perform any data modeling we will require the balanced dataset either that will impact on accuracy of the model.
# we can use the different techniques to make data balanced such as Oversampling techniques and SMOTE technique
# Out:
# 5    577
# 6    535
# 7    167
# 4     53
# 8     17
# 3     10
# Name: quality, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.boxplot(wine_data.quality)
# Out:
# <Axes: >

# %%
wine_data.quality.value_counts().plot(kind='bar')
plt.xlabel('winequality')
plt.ylabel('Count')
plt.show()

# %%
wine_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
for column in wine_data.columns:
    sns.histplot(wine_data[column],kde=True)

# %%
for column in wine_data.columns:
    plt.figure(figsize=(10,6))
    sns.histplot(wine_data[column],kde=True)

# %%
sns.histplot(wine_data['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
sns.pairplot(wine_data)

# %%
# categorical Plot
sns.catplot(x='quality',y='alcohol',data=wine_data, kind='box')

# %%
sns.scatterplot(x='alcohol',y='pH', hue='quality',data=wine_data)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>
